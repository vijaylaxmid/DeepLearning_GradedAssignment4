# %%
import keras
from keras.datasets import cifar100
from keras.preprocessing.image import ImageDataGenerator
from keras.models import Sequential
from keras.layers import Dense, Dropout, Activation, Flatten
from keras.layers import Conv2D, MaxPooling2D, BatchNormalization
from keras import optimizers
import numpy as np
from keras.layers.core import Lambda
from keras import backend as K
from keras import regularizers

# %%
class cifar100vgg:
    def __init__(self,train=True):
        self.num_classes = 100
        self.weight_decay = 0.0005
        self.x_shape = [32,32,3]

        self.model = self.build_model()
        if train:
            self.model = self.train(self.model)
        else:
            self.model.load_weights('cifar100vgg.h5')


    def build_model(self):
        # Build the network of vgg for 10 classes with massive dropout and weight decay as described in the paper.

        model = Sequential()
        weight_decay = self.weight_decay

        model.add(Conv2D(64, (3, 3), padding='same',
                         input_shape=self.x_shape,kernel_regularizer=regularizers.l2(weight_decay)))
        model.add(Activation('relu'))
        model.add(BatchNormalization())
        model.add(Dropout(0.3))

        model.add(Conv2D(64, (3, 3), padding='same',kernel_regularizer=regularizers.l2(weight_decay)))
        model.add(Activation('relu'))
        model.add(BatchNormalization())

        model.add(MaxPooling2D(pool_size=(2, 2)))

        model.add(Conv2D(128, (3, 3), padding='same',kernel_regularizer=regularizers.l2(weight_decay)))
        model.add(Activation('relu'))
        model.add(BatchNormalization())
        model.add(Dropout(0.4))

        model.add(Conv2D(128, (3, 3), padding='same',kernel_regularizer=regularizers.l2(weight_decay)))
        model.add(Activation('relu'))
        model.add(BatchNormalization())

        model.add(MaxPooling2D(pool_size=(2, 2)))

        model.add(Conv2D(256, (3, 3), padding='same',kernel_regularizer=regularizers.l2(weight_decay)))
        model.add(Activation('relu'))
        model.add(BatchNormalization())
        model.add(Dropout(0.4))

        model.add(Conv2D(256, (3, 3), padding='same',kernel_regularizer=regularizers.l2(weight_decay)))
        model.add(Activation('relu'))
        model.add(BatchNormalization())
        model.add(Dropout(0.4))

        model.add(Conv2D(256, (3, 3), padding='same',kernel_regularizer=regularizers.l2(weight_decay)))
        model.add(Activation('relu'))
        model.add(BatchNormalization())

        model.add(MaxPooling2D(pool_size=(2, 2)))


        model.add(Conv2D(512, (3, 3), padding='same',kernel_regularizer=regularizers.l2(weight_decay)))
        model.add(Activation('relu'))
        model.add(BatchNormalization())
        model.add(Dropout(0.4))

        model.add(Conv2D(512, (3, 3), padding='same',kernel_regularizer=regularizers.l2(weight_decay)))
        model.add(Activation('relu'))
        model.add(BatchNormalization())
        model.add(Dropout(0.4))

        model.add(Conv2D(512, (3, 3), padding='same',kernel_regularizer=regularizers.l2(weight_decay)))
        model.add(Activation('relu'))
        model.add(BatchNormalization())

        model.add(MaxPooling2D(pool_size=(2, 2)))


        model.add(Conv2D(512, (3, 3), padding='same',kernel_regularizer=regularizers.l2(weight_decay)))
        model.add(Activation('relu'))
        model.add(BatchNormalization())
        model.add(Dropout(0.4))

        model.add(Conv2D(512, (3, 3), padding='same',kernel_regularizer=regularizers.l2(weight_decay)))
        model.add(Activation('relu'))
        model.add(BatchNormalization())
        model.add(Dropout(0.4))

        model.add(Conv2D(512, (3, 3), padding='same',kernel_regularizer=regularizers.l2(weight_decay)))
        model.add(Activation('relu'))
        model.add(BatchNormalization())

        model.add(MaxPooling2D(pool_size=(2, 2)))
        model.add(Dropout(0.5))

        model.add(Flatten())
        model.add(Dense(512,kernel_regularizer=regularizers.l2(weight_decay)))
        model.add(Activation('relu'))
        model.add(BatchNormalization())

        model.add(Dropout(0.5))
        model.add(Dense(self.num_classes))
        model.add(Activation('softmax'))
        return model


    def normalize(self,X_train,X_test):
        #this function normalize inputs for zero mean and unit variance
        # it is used when training a model.
        # Input: training set and test set
        # Output: normalized training set and test set according to the trianing set statistics.
        mean = np.mean(X_train,axis=(0,1,2,3))
        std = np.std(X_train, axis=(0, 1, 2, 3))
        print(mean)
        print(std)
        X_train = (X_train-mean)/(std+1e-7)
        X_test = (X_test-mean)/(std+1e-7)
        return X_train, X_test

    def normalize_production(self,x):
        #this function is used to normalize instances in production according to saved training set statistics
        # Input: X - a training set
        # Output X - a normalized training set according to normalization constants.

        #these values produced during first training and are general for the standard cifar10 training set normalization
        mean = 121.936
        std = 68.389
        return (x-mean)/(std+1e-7)

    def predict(self,x,normalize=True,batch_size=50):
        if normalize:
            x = self.normalize_production(x)
        return self.model.predict(x,batch_size)

    def train(self,model):

        #training parameters
        batch_size = 128
        maxepoches = 50
        learning_rate = 0.1
        lr_decay = 1e-6
        lr_drop = 20

        # The data, shuffled and split between train and test sets:
        (x_train, y_train), (x_test, y_test) = cifar100.load_data()
        x_train = x_train.astype('float32')
        x_test = x_test.astype('float32')
        x_train, x_test = self.normalize(x_train, x_test)

        y_train = keras.utils.to_categorical(y_train, self.num_classes)
        y_test = keras.utils.to_categorical(y_test, self.num_classes)


        def lr_scheduler(epoch):
            return learning_rate * (0.5 ** (epoch // lr_drop))
        reduce_lr = keras.callbacks.LearningRateScheduler(lr_scheduler)


        #data augmentation
        datagen = ImageDataGenerator(
            featurewise_center=False,  # set input mean to 0 over the dataset
            samplewise_center=False,  # set each sample mean to 0
            featurewise_std_normalization=False,  # divide inputs by std of the dataset
            samplewise_std_normalization=False,  # divide each input by its std
            zca_whitening=False,  # apply ZCA whitening
            rotation_range=15,  # randomly rotate images in the range (degrees, 0 to 180)
            width_shift_range=0.1,  # randomly shift images horizontally (fraction of total width)
            height_shift_range=0.1,  # randomly shift images vertically (fraction of total height)
            horizontal_flip=True,  # randomly flip images
            vertical_flip=False)  # randomly flip images
        # (std, mean, and principal components if ZCA whitening is applied).
        datagen.fit(x_train)



        #optimization details
        sgd = optimizers.SGD(lr=learning_rate, decay=lr_decay, momentum=0.9, nesterov=True)
        model.compile(loss='categorical_crossentropy', optimizer=sgd,metrics=['accuracy'])


        # training process in a for loop with learning rate drop every 25 epoches.

        historytemp = model.fit_generator(datagen.flow(x_train, y_train,
                                         batch_size=batch_size),
                            steps_per_epoch=x_train.shape[0] // batch_size,
                            epochs=maxepoches,
                            validation_data=(x_test, y_test),callbacks=[reduce_lr],verbose=2)
        model.save_weights('cifar100vgg.h5')
        return model

if __name__ == '__main__':
    (x_train, y_train), (x_test, y_test) = cifar100.load_data()
    x_train = x_train.astype('float32')
    x_test = x_test.astype('float32')

    y_train = keras.utils.to_categorical(y_train, 100)
    y_test = keras.utils.to_categorical(y_test, 100)

    model = cifar100vgg()

    predicted_x = model.predict(x_test)
    residuals = (np.argmax(predicted_x,1)!=np.argmax(y_test,1))
    loss = sum(residuals)/len(residuals)
    print("the validation 0/1 loss is: ",loss)
# Out:
# 121.93584
# 68.38902
# Epoch 1/50
#  - 33s - loss: 23.7113 - accuracy: 0.0255 - val_loss: 17.6916 - val_accuracy: 0.0188
# Epoch 2/50
#  - 30s - loss: 13.3296 - accuracy: 0.0459 - val_loss: 11.0168 - val_accuracy: 0.0276
# Epoch 3/50
#  - 30s - loss: 8.3189 - accuracy: 0.0631 - val_loss: 7.5669 - val_accuracy: 0.0234
# Epoch 4/50
#  - 30s - loss: 6.0167 - accuracy: 0.0784 - val_loss: 5.5271 - val_accuracy: 0.0693
# Epoch 5/50
#  - 30s - loss: 4.9542 - accuracy: 0.0963 - val_loss: 4.6493 - val_accuracy: 0.1059
# Epoch 6/50
#  - 30s - loss: 4.4497 - accuracy: 0.1085 - val_loss: 4.2614 - val_accuracy: 0.1335
# Epoch 7/50
#  - 30s - loss: 4.1534 - accuracy: 0.1323 - val_loss: 4.2605 - val_accuracy: 0.1318
# Epoch 8/50
#  - 30s - loss: 3.9862 - accuracy: 0.1594 - val_loss: 3.8631 - val_accuracy: 0.1820
# Epoch 9/50
#  - 30s - loss: 3.8899 - accuracy: 0.1808 - val_loss: 3.7566 - val_accuracy: 0.2090
# Epoch 10/50
#  - 30s - loss: 3.8358 - accuracy: 0.2021 - val_loss: 4.0328 - val_accuracy: 0.2003
# Epoch 11/50
#  - 30s - loss: 3.7900 - accuracy: 0.2287 - val_loss: 3.6671 - val_accuracy: 0.2572
# Epoch 12/50
#  - 30s - loss: 3.7482 - accuracy: 0.2494 - val_loss: 4.0652 - val_accuracy: 0.2448
# Epoch 13/50
#  - 30s - loss: 3.7366 - accuracy: 0.2656 - val_loss: 3.7130 - val_accuracy: 0.2813
# Epoch 14/50
#  - 29s - loss: 3.7423 - accuracy: 0.2809 - val_loss: 3.7801 - val_accuracy: 0.2751
# Epoch 15/50
#  - 29s - loss: 3.7554 - accuracy: 0.2904 - val_loss: 3.6631 - val_accuracy: 0.3214
# Epoch 16/50
#  - 29s - loss: 3.7494 - accuracy: 0.3018 - val_loss: 3.5730 - val_accuracy: 0.3473
# Epoch 17/50
#  - 29s - loss: 3.7684 - accuracy: 0.3104 - val_loss: 3.5437 - val_accuracy: 0.3552
# Epoch 18/50
#  - 29s - loss: 3.7840 - accuracy: 0.3186 - val_loss: 4.4370 - val_accuracy: 0.2443
# Epoch 19/50
#  - 29s - loss: 3.8034 - accuracy: 0.3255 - val_loss: 3.7513 - val_accuracy: 0.3390
# Epoch 20/50
#  - 29s - loss: 3.8184 - accuracy: 0.3311 - val_loss: 3.7388 - val_accuracy: 0.3569
# Epoch 21/50
#  - 29s - loss: 3.4963 - accuracy: 0.3866 - val_loss: 3.2378 - val_accuracy: 0.4362
# Epoch 22/50
#  - 29s - loss: 3.3196 - accuracy: 0.4032 - val_loss: 3.2031 - val_accuracy: 0.4278
# Epoch 23/50
#  - 29s - loss: 3.2743 - accuracy: 0.4059 - val_loss: 3.2266 - val_accuracy: 0.4140
# Epoch 24/50
#  - 29s - loss: 3.2621 - accuracy: 0.4111 - val_loss: 3.1513 - val_accuracy: 0.4386
# Epoch 25/50
#  - 29s - loss: 3.2707 - accuracy: 0.4137 - val_loss: 3.4519 - val_accuracy: 0.4064
# Epoch 26/50
#  - 29s - loss: 3.2791 - accuracy: 0.4186 - val_loss: 3.3586 - val_accuracy: 0.4106
# Epoch 27/50
#  - 29s - loss: 3.2835 - accuracy: 0.4235 - val_loss: 3.1473 - val_accuracy: 0.4489
# Epoch 28/50
#  - 29s - loss: 3.2942 - accuracy: 0.4231 - val_loss: 3.1754 - val_accuracy: 0.4618
# Epoch 29/50
#  - 29s - loss: 3.2954 - accuracy: 0.4286 - val_loss: 3.1459 - val_accuracy: 0.4679
# Epoch 30/50
#  - 30s - loss: 3.3040 - accuracy: 0.4343 - val_loss: 3.2694 - val_accuracy: 0.4553
# Epoch 31/50
#  - 30s - loss: 3.2958 - accuracy: 0.4411 - val_loss: 3.3253 - val_accuracy: 0.4475
# Epoch 32/50
#  - 29s - loss: 3.3072 - accuracy: 0.4406 - val_loss: 3.2749 - val_accuracy: 0.4515
# Epoch 33/50
#  - 29s - loss: 3.3333 - accuracy: 0.4411 - val_loss: 3.2798 - val_accuracy: 0.4649
# Epoch 34/50
#  - 29s - loss: 3.3275 - accuracy: 0.4463 - val_loss: 3.2022 - val_accuracy: 0.4784
# Epoch 35/50
#  - 29s - loss: 3.3278 - accuracy: 0.4484 - val_loss: 3.2528 - val_accuracy: 0.4699
# Epoch 36/50
#  - 29s - loss: 3.3359 - accuracy: 0.4500 - val_loss: 3.2789 - val_accuracy: 0.4655
# Epoch 37/50
#  - 29s - loss: 3.3419 - accuracy: 0.4494 - val_loss: 3.2123 - val_accuracy: 0.4875
# Epoch 38/50
#  - 29s - loss: 3.3289 - accuracy: 0.4557 - val_loss: 3.2683 - val_accuracy: 0.4691
# Epoch 39/50
#  - 29s - loss: 3.3515 - accuracy: 0.4560 - val_loss: 3.5077 - val_accuracy: 0.4417
# Epoch 40/50
#  - 29s - loss: 3.3505 - accuracy: 0.4616 - val_loss: 3.3520 - val_accuracy: 0.4667
# Epoch 41/50
#  - 29s - loss: 3.0874 - accuracy: 0.5085 - val_loss: 2.9399 - val_accuracy: 0.5318
# Epoch 42/50
#  - 29s - loss: 2.9435 - accuracy: 0.5215 - val_loss: 2.8761 - val_accuracy: 0.5354
# Epoch 43/50
#  - 29s - loss: 2.8680 - accuracy: 0.5316 - val_loss: 2.8226 - val_accuracy: 0.5426
# Epoch 44/50
#  - 29s - loss: 2.8262 - accuracy: 0.5332 - val_loss: 3.0118 - val_accuracy: 0.4986
# Epoch 45/50
#  - 29s - loss: 2.8258 - accuracy: 0.5307 - val_loss: 2.7688 - val_accuracy: 0.5466
# Epoch 46/50
#  - 29s - loss: 2.8129 - accuracy: 0.5302 - val_loss: 2.9763 - val_accuracy: 0.5118
# Epoch 47/50
#  - 29s - loss: 2.8018 - accuracy: 0.5347 - val_loss: 2.7709 - val_accuracy: 0.5472
# Epoch 48/50
#  - 29s - loss: 2.8077 - accuracy: 0.5356 - val_loss: 2.8198 - val_accuracy: 0.5434
# Epoch 49/50
#  - 29s - loss: 2.8002 - accuracy: 0.5404 - val_loss: 3.0578 - val_accuracy: 0.5012
# Epoch 50/50
#  - 29s - loss: 2.8035 - accuracy: 0.5388 - val_loss: 2.8429 - val_accuracy: 0.5376
# the validation 0/1 loss is:  0.4624
